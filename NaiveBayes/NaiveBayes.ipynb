# %% [markdown]
# # Naive Bayes Model
#
#  #### P(A|B) = P(AnB) / P(B)
#  #### P(AnB) = P(A|B) / P(B)
#  #### P(B|A) * P(A) = P(A|B) * P(B)
#  #### P(B|A) = P(A|B) * P(B) / P(A)

# %%
import re
from collections import defaultdict
import pandas as pd
import numpy as np 
import os
import math

#csv 파일 불러옵니다. 데이터셋은 keggle의 무료데이터셋을 이용하였습니다.
load_csv = pd.read_csv(os.getcwd()+'/dataset/spam.csv',encoding='latin-1')

#데이터 형식이 어떻게 이루어져 있는지 상위 10개를 꺼내와 확인합니다.
load_csv.head(10)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6   ham  Even my brother is not like to speak with me. ...        NaN
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
# 8  spam  WINNER!! As a valued network customer you have...        NaN
# 9  spam  Had your mobile 11 months or more? U R entitle...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
# 9        NaN        NaN

# %%
#필요없는  column (Unnamed:2 , Unnamed: 3 , Unnamed: 4) 삭제합니다. 
load_csv = load_csv.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1)

#라벨형식을 스팸일때 0 햄일때 1 으로 바꾸어 줍니다.
load_csv["v1"]=load_csv["v1"].apply(lambda x:1 if x=="spam" else 0) 

#column 이름 재지정
load_csv = load_csv.rename(columns = {'v1':'Class','v2':'Text'})

#cloum 위치 변경
load_csv = pd.DataFrame(load_csv, columns=['Text', 'Class'])

#데이터 랜덤하게 섞어줍니다. 
load_csv = load_csv.sample(frac=1).reset_index(drop=True)

#데이터를 [['메일 내용' , '0 or 1' ] , ['메일내용' , '0  or 1']] 의 형식으로 바꾸어 줍니다.
text = load_csv['Text']
text = list(text)

label = load_csv['Class']
label = list(label)

data = [x for x in zip(text,label)]

# 학습데이터와 테스트데이터를 7:3 의 비율로 나누어 줍니다. 
train_data = data[:int(len(data)*0.7)]
test_data = data[int(len(data)*0.7):]

#데이터 형식을 알아보기위해 학습데이터의 shape 을 확인합니다.
print(train_data[:3])
# Out:
# [("What's up bruv, hope you had a great break. Do have a rewarding semester.", 0), ('Wif my family booking tour package.', 0), ('He said that he had a right giggle when he saw u again! You would possibly be the first person2die from NVQ, but think how much you could for! ', 0)]

# %%
#문장을 단어로 분해해 주는 함수를 만듭니다. [a-z0-9]+ 는 정규식입니다.
def tokenize(message):
    message = message.lower()
    all_words = re.findall("[a-z0-9]+",message)
    return set(all_words)


# (단어)  : [  스팸메세지에서 나온 빈도수] [스팸이 아닌 메시지에서 나온 빈도수]
def count_words(training_set):
    counts = defaultdict(lambda:[0,0])
    for message, is_spam in training_set:
        for word in tokenize(message):
            counts[word][0 if is_spam else 1] += 1
            
    return counts

# [단어, 스팸 메시지에서 단어가 나올 확률, 스팸이 아닌 메시지에서 단어가 나올 확률]
# k = 0.5 는 가짜 빈도수를 뜻합니다 . 가짜 빈도수를 사용 안할경우 : 만일 ham 메일에서만 '나비' 라는
#단어가 나왔을 때  spam 에서 '나비모양의 가방을 싸게 판매합니다 ' 의 메일도 ham메일로 예측하기 때문에
#가짜 빈도수를 넣어줍니다.
def word_probabilities(counts, total_spams, total_non_spam,k=0.5):
    return [(w,
            (spam+k) / (total_spams + 2*k),
            (non_spam + k) / (total_non_spam + 2*k))
           for w , (spam,non_spam) in counts.items()]

#단어의 확률을 사용해서 메세지가 스팸일 확률을 계산합니다.
def spam_probability(word_probs , message):
    message_words = tokenize(message)
    log_prob_if_spam = log_prob_if_not_spam = 0.0
    
    #모든 단어에 대해서 반복합니다.
    for word , prob_if_spam, prob_if_not_spam in word_probs:
        
        #만약에 메세지에 word 가 나타나면 해당 단어가 나올 log  확률을 더해줍니다.
        if word in message_words:
            log_prob_if_spam += math.log(prob_if_spam)
            log_prob_if_not_spam += math.log(prob_if_not_spam)
        else:
            log_prob_if_spam += math.log(1- prob_if_spam)
            log_prob_if_not_spam += math.log(1 - prob_if_not_spam)
    prob_if_spam = math.exp(log_prob_if_spam)
    prob_if_not_spam = math.exp(log_prob_if_not_spam)
    return prob_if_spam / (prob_if_spam + prob_if_not_spam)

#최종적으로 만들어 놓은 함수들을 이용하여 나이브 베이즈 모델을 만듭니다.
class NaiveBayes:
    def __init__(self,k=0.5):
        self.k = k
        self.word_prob = []
        
    def train(self,training_set):
        # 트레이닝 데이터에서 스팸메일의 개수
        num_spams = len([is_spam for message, is_spam in training_set if is_spam])
       # 트레이닝 데이터에서 햄메일의 개수
        num_non_spams = len(training_set)-num_spams
        
        word_counts = count_words(training_set)
        
        self.word_probs = word_probabilities(word_counts,num_spams,num_non_spams,self.k)
    def classify(self,message):
        return spam_probability(self.word_probs,message)
        
classifier = NaiveBayes()
classifier.train(train_data)

classified = [(subject, is_spam ,classifier.classify(subject))
             for subject, is_spam in test_data]

#스팸일 확률이 50% 넘을 때 스팸메일의 내용과 확률을 출력하기 위해 사용됩니다.
for i in range(len(classified)):
    if classified[i][2]>0.5:
        print(classified[i])
# Out:
# ('FreeMsg: Claim ur 250 SMS messages-Text OK to 84025 now!Use web2mobile 2 ur mates etc. Join Txt250.com for 1.50p/wk. T&C BOX139, LA32WU. 16 . Remove txtX or stop', 1, 1.0)
# ('SMS SERVICES. for your inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP, no extra charge. help 08702840625.COMUK. 220-CM2 9AE', 1, 1.0)
# ('U\x89Ûªve Bin Awarded å£50 to Play 4 Instant Cash. Call 08715203028 To Claim. EVERY 9th Player Wins Min å£50-å£500. OptOut 08718727870', 1, 0.9999999999999972)
# ('Hi, this is Mandy Sullivan calling from HOTMIX FM...you are chosen to receive å£5000.00 in our Easter Prize draw.....Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else....', 1, 1.0)
# ("UpgrdCentre Orange customer, you may now claim your FREE CAMERA PHONE upgrade for your loyalty. Call now on 0207 153 9153. Offer ends 26th July. T&C's apply. Opt-out available", 1, 1.0)
# ('Hope you enjoyed your new content. text stop to 61610 to unsubscribe. help:08712400602450p Provided by tones2you.co.uk', 1, 0.9999999901817946)
# ('WINNER!! As a valued network customer you have been selected to receivea å£900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.', 1, 1.0)
# ('This message is free. Welcome to the new & improved Sex & Dogging club! To unsubscribe from this service reply STOP. msgs@150p 18+only', 1, 1.0)
# ('Xmas Offer! Latest Motorola, SonyEricsson & Nokia & FREE Bluetooth or DVD! Double Mins & 1000 Txt on Orange. Call MobileUpd8 on 08000839402 or call2optout/4QF2', 1, 1.0)
# ('Marvel Mobile Play the official Ultimate Spider-man game (å£4.50) on ur mobile right now. Text SPIDER to 83338 for the game & we ll send u a FREE 8Ball wallpaper', 1, 0.999996191276869)
# ('FreeMsg Hi baby wow just got a new cam moby. Wanna C a hot pic? or Fancy a chat?Im w8in 4uTxt / rply CHAT to 82242 Hlp 08712317606 Msg150p 2rcv', 1, 0.999999999987448)
# ('URGENT! Your Mobile number has been awarded with a å£2000 prize GUARANTEED. Call 09058094454 from land line. Claim 3030. Valid 12hrs only', 1, 1.0)
# ('PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08715203694 Identifier Code: 40533 Expires 31/10/04', 1, 1.0)
# ('SMS SERVICES For your inclusive text credits pls gotto www.comuk.net login 3qxj9 unsubscribe with STOP no extra charge help 08702840625 comuk.220cm2 9AE', 1, 1.0)
# ('Valentines Day Special! Win over å£1000 in our quiz and take your partner on the trip of a lifetime! Send GO to 83600 now. 150p/msg rcvd. CustCare:08718720201', 1, 1.0)
# ('Call FREEPHONE 0800 542 0578 now!', 1, 0.5496810645144891)
# ('Thanks for your Ringtone Order, Reference T91. You will be charged GBP 4 per week. You can unsubscribe at anytime by calling customer services on 09057039994', 1, 0.9999999997061817)
# ('Last chance 2 claim ur å£150 worth of discount vouchers-Text YES to 85023 now!SavaMob-member offers mobile T Cs 08717898035. å£3.00 Sub. 16 . Remove txt X or STOP', 1, 1.0)
# ('You have been specially selected to receive a \\3000 award! Call 08712402050 BEFORE the lines close. Cost 10ppm. 16+. T&Cs apply. AG Promo"', 1, 1.0)
# ('Dear Voucher Holder, To claim this weeks offer, at your PC please go to http://www.wtlp.co.uk/text. Ts&Cs apply.', 1, 1.0)
# ('Urgent! call 09066612661 from landline. Your complementary 4* Tenerife Holiday or å£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18+ Sender: Hol Offer', 1, 1.0)
# ('Welcome to UK-mobile-date this msg is FREE giving you free calling to 08719839835. Future mgs billed at 150p daily. To cancel send \\go stop\\" to 89123"', 1, 0.999999999987501)
# ('URGENT! We are trying to contact U. Todays draw shows that you have won a å£800 prize GUARANTEED. Call 09050001808 from land line. Claim M95. Valid12hrs only', 1, 1.0)
# ('Free Top ringtone -sub to weekly ringtone-get 1st week free-send SUBPOLY to 81618-?3 per week-stop sms-08718727870', 1, 0.9999999999998785)
# ('Not heard from U4 a while. Call 4 rude chat private line 01223585334 to cum. Wan 2C pics of me gettin shagged then text PIX to 8552. 2End send STOP 8552 SAM xxx', 1, 0.9999999999999993)
# ('You are a winner you have been specially selected to receive å£1000 cash or a å£2000 award. Speak to a live operator to claim call 087147123779am-7pm. Cost 10p', 1, 1.0)
# ('Urgent UR awarded a complimentary trip to EuroDisinc Trav, Aco&Entry41 Or å£1000. To claim txt DIS to 87121 18+6*å£1.50(moreFrmMob. ShrAcomOrSglSuplt)10, LS1 3AJ', 1, 1.0)
# ('As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a å£1500 Bonus Prize, call 09066364589', 1, 1.0)
# ('You have WON a guaranteed å£1000 cash or a å£2000 prize.To claim yr prize call our customer service representative on', 1, 1.0)
# ('URGENT! Your mobile No 07xxxxxxxxx won a å£2,000 bonus caller prize on 02/06/03! this is the 2nd attempt to reach YOU! call 09066362231 ASAP! BOX97N7QP, 150PPM', 1, 1.0)
# ('Dear Voucher Holder, 2 claim this weeks offer, at your PC go to http://www.e-tlp.co.uk/expressoffer Ts&Cs apply.2 stop texts txt STOP to 80062.', 1, 1.0)
# ('Spook up your mob with a Halloween collection of a logo & pic message plus a free eerie tone, txt CARD SPOOK to 8007 zed 08701417012150p per logo/pic ', 1, 1.0)
# ("important information 4 orange user 0789xxxxxxx. today is your lucky day!2find out why log onto http://www.urawinner.com THERE'S A FANTASTIC SURPRISE AWAITING YOU!", 1, 0.9999999999999999)
# ('Thanks for your ringtone order, ref number R836. Your mobile will be charged å£4.50. Should your tone not arrive please call customer services on 09065069154', 1, 0.9999999999999959)
# ('HOT LIVE FANTASIES call now 08707500020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call', 1, 1.0)
# ("25p 4 alfie Moon's Children in need song on ur mob. Tell ur m8s. Txt Tone charity to 8007 for Nokias or Poly charity for polys: zed 08701417012 profit 2 charity.", 1, 1.0)
# ('Ringtone Club: Get the UK singles chart on your mobile each week and choose any top quality ringtone! This message is free of charge.', 1, 0.9999999999993623)
# ('December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906', 1, 1.0)
# ('Will u meet ur dream partner soon? Is ur career off 2 a flyng start? 2 find out free, txt HORO followed by ur star sign, e. g. HORO ARIES', 1, 0.9612664620070797)
# ('UR awarded a City Break and could WIN a å£200 Summer Shopping spree every WK. Txt STORE to 88039.SkilGme.TsCs087147403231Winawk!Age16+å£1.50perWKsub', 1, 1.0)
# ('Last Chance! Claim ur å£150 worth of discount vouchers today! Text SHOP to 85023 now! SavaMob, offers mobile! T Cs SavaMob POBOX84, M263UZ. å£3.00 Sub. 16', 1, 1.0)
# ('U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094594', 1, 0.9999999923030345)
# ('URGENT! Your Mobile No. was awarded å£2000 Bonus Caller Prize on 5/9/03 This is our final try to contact U! Call from Landline 09064019788 BOX42WR29C, 150PPM', 1, 1.0)
# ('New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today! From ONLY å£1. www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION.', 1, 1.0)
# ('Thank you, winner notified by sms. Good Luck! No future marketing reply STOP to 84122 customer services 08450542832', 1, 0.9991626953571088)
# ('U were outbid by simonwatson5120 on the Shinco DVD Plyr. 2 bid again, visit sms. ac/smsrewards 2 end bid notifications, reply END OUT', 1, 0.9949697284207574)
# ('GENT! We are trying to contact you. Last weekends draw shows that you won a å£1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm', 1, 1.0)
# ('Urgent! Please call 09061213237 from landline. å£5000 cash or a luxury 4* Canary Islands Holiday await collection. T&Cs SAE PO Box 177. M227XY. 150ppm. 16+', 1, 1.0)
# ('As a Registered Subscriber yr draw 4 a å£100 gift voucher will b entered on receipt of a correct ans. When are the next olympics. Txt ans to 80062', 1, 0.9999999999990791)
# ('SMS AUCTION You have won a Nokia 7250i. This is what you get when you win our FREE auction. To take part send Nokia to 86021 now. HG/Suite342/2Lands Row/W1JHL 16+', 1, 1.0)
# ('URGENT!! Your 4* Costa Del Sol Holiday or å£5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, Costå£1.50/pm, Max10mins', 1, 1.0)
# ("I don't know u and u don't know me. Send CHAT to 86688 now and let's find each other! Only 150p/Msg rcvd. HG/Suite342/2Lands/Row/W1J6HL LDN. 18 years or over.", 1, 1.0)
# ('You have won a Nokia 7250i. This is what you get when you win our FREE auction. To take part send Nokia to 86021 now. HG/Suite342/2Lands Row/W1JHL 16+ ', 1, 1.0)
# ('You have an important customer service announcement from PREMIER. Call FREEPHONE 0800 542 0578 now!', 1, 0.9999999984053181)
# ('England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/Ì¼1.20 POBOXox36504W45WQ 16+', 1, 0.999999999997462)
# ('You have won a guaranteed å£200 award or even å£1000 cashto claim UR award call free on 08000407165 (18+) 2 stop getstop on 88222 PHP. RG21 4JX', 1, 1.0)
# ("Please call Amanda with regard to renewing or upgrading your current T-Mobile handset free of charge. Offer ends today. Tel 0845 021 3680 subject to T's and C's", 1, 0.9999999996688859)
# ('CDs 4u: Congratulations ur awarded å£500 of CD gift vouchers or å£125 gift guaranteed & Freeentry 2 å£100 wkly draw xt MUSIC to 87066 TnCs www.ldew.com1win150ppmx3age16 ', 1, 1.0)
# ('4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths+? Call MobilesDirect free on 08000938767 to update now! or2stoptxt T&Cs', 1, 1.0)
# ('Do you want a New Nokia 3510i Colour Phone Delivered Tomorrow? With 200 FREE minutes to any mobile + 100 FREE text + FREE camcorder Reply or Call 8000930705', 1, 1.0)
# ('We tried to contact you re our offer of New Video Phone 750 anytime any network mins HALF PRICE Rental camcorder call 08000930705 or reply for delivery Wed', 1, 1.0)
# ('FREE MESSAGE Activate your 500 FREE Text Messages by replying to this message with the word FREE For terms & conditions, visit www.07781482378.com', 1, 0.9999999999871084)
# ('WIN a year supply of CDs 4 a store of ur choice worth å£500 & enter our å£100 Weekly draw txt MUSIC to 87066 Ts&Cs www.Ldew.com.subs16+1win150ppmx3', 1, 1.0)
# ('SplashMobile: Choose from 1000s of gr8 tones each wk! This is a subscrition service with weekly tones costing 300p. U have one credit - kick back and ENJOY', 1, 0.9999999999542288)
# ('You have WON a guaranteed å£1000 cash or a å£2000 prize. To claim yr prize call our customer service representative on 08714712394 between 10am-7pm', 1, 1.0)
# ("Free-message: Jamster!Get the crazy frog sound now! For poly text MAD1, for real text MAD2 to 88888. 6 crazy sounds for just 3 GBP/week! 16+only! T&C's apply", 1, 0.9999999999936056)
# ('YES! The only place in town to meet exciting adult singles is now in the UK. Txt CHAT to 86688 now! 150p/Msg.', 1, 0.9999999996698803)
# ('Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE! Call MobileUpd8 free on 08000839402 NOW! or 2stoptxt T&Cs', 1, 1.0)
# ('cmon babe, make me horny, *turn* me on! Txt me your fantasy now babe -) Im hot, sticky and need you now. All replies cost å£1.50. 2 cancel send STOP', 1, 0.999999969717494)
# ('Final Chance! Claim ur å£150 worth of discount vouchers today! Text YES to 85023 now! SavaMob, member offers mobile! T Cs SavaMob POBOX84, M263UZ. å£3.00 Subs 16', 1, 1.0)
# ('FreeMsg Hey U, i just got 1 of these video/pic fones, reply WILD to this txt & ill send U my pics, hurry up Im so bored at work xxx (18 150p/rcvd STOP2stop)', 1, 0.9999999573434744)
# ('Bored housewives! Chat n date now! 0871750.77.11! BT-national rate 10p/min only from landlines!', 1, 0.9999999999972389)
# ('Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records.', 1, 1.0)
# ('Congratulations ur awarded either å£500 of CD gift vouchers & Free entry 2 our å£100 weekly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16', 1, 1.0)
# ('PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08718738002 Identifier Code: 48922 Expires 21/11/04', 1, 1.0)
# ("network operator. The service is free. For T & C's visit 80488.biz", 1, 0.9999910533962227)
# ('Get 3 Lions England tone, reply lionm 4 mono or lionp 4 poly. 4 more go 2 www.ringtones.co.uk, the original n best. Tones 3GBP network operator rates apply.', 1, 1.0)
# ('Thanks for your ringtone order, reference number X49. Your mobile will be charged 4.50. Should your tone not arrive please call customer services 09065989182. From: [colour=red]text[/colour]TXTstar', 1, 1.0)
# ('Free msg: Single? Find a partner in your area! 1000s of real people are waiting to chat now!Send CHAT to 62220Cncl send STOPCS 08717890890å£1.50 per msg', 1, 0.9999999582550393)
# ('<Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS alert. You have 4 messages. You have 21 matches. Please call back on 09056242159 to retrieve your messages and matches', 1, 0.9999999999993279)
# ('RECPT 1/3. You have ordered a Ringtone. Your order is being processed...', 1, 0.9420271807818831)
# ('22 days to kick off! For Euro2004 U will be kept up to date with the latest news and results daily. To be removed send GET TXT STOP to 83222', 1, 0.9999999868984134)
# ('URGENT! We are trying to contact U Todays draw shows that you have won a å£800 prize GUARANTEED. Call 09050000460 from land line. Claim J89. po box245c2150pm', 1, 1.0)
# ('GENT! We are trying to contact you. Last weekends draw shows that you won a å£1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm ', 1, 1.0)
# ('Moby Pub Quiz.Win a å£100 High Street prize if u know who the new Duchess of Cornwall will be? Txt her first name to 82277.unsub STOP å£1.50 008704050406 SP Arrow', 1, 1.0)
# ('Sorry! U can not unsubscribe yet. THE MOB offer package has a min term of 54 weeks> pls resubmit request after expiry. Reply THEMOB HELP 4 more info', 1, 0.9999997264237672)
# ('SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info', 1, 1.0)
# ('Do you want a new Video phone? 600 anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free delTOMORROW call 08002888812 or reply NOW', 1, 1.0)
# ('URGENT! We are trying to contact U. Todays draw shows that you have won a å£800 prize GUARANTEED. Call 09050003091 from land line. Claim C52. Valid 12hrs only', 1, 1.0)
# ('FREE entry into our å£250 weekly competition just text the word WIN to 80086 NOW. 18 T&C www.txttowin.co.uk', 1, 1.0)
# ('XMAS iscoming & ur awarded either å£500 CD gift vouchers & free entry 2 r å£100 weekly draw txt MUSIC to 87066 TnC www.Ldew.com1win150ppmx3age16subscription ', 1, 1.0)
# ('Dear Voucher Holder, To claim this weeks offer, at you PC please go to http://www.e-tlp.co.uk/reward. Ts&Cs apply.', 1, 1.0)
# ('Think ur smart ? Win å£200 this week in our weekly quiz, text PLAY to 85222 now!T&Cs WinnersClub PO BOX 84, M26 3UZ. 16+. GBP1.50/week', 1, 1.0)
# ('Congrats! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16+ Close 300603 post BCM4284 Ldn WC1N3XX', 1, 1.0)
# ('Urgent! call 09061749602 from Landline. Your complimentary 4* Tenerife Holiday or å£10,000 cash await collection SAE T&Cs BOX 528 HP20 1YF 150ppm 18+', 1, 1.0)
# ('Loans for any purpose even if you have Bad Credit! Tenants Welcome. Call NoWorriesLoans.com on 08717111821', 1, 0.9534765040007237)
# ('FREE for 1st week! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p/tone 16+', 1, 1.0)
# ('PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires', 1, 1.0)
# ('U can WIN å£100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.ldew.com SkillGame,1Winaweek, age16.150ppermessSubscription', 1, 1.0)
# ('For your chance to WIN a FREE Bluetooth Headset then simply reply back with \\ADP\\""', 1, 0.9992439345197279)
# ('Free Msg: Ringtone!From: http://tms. widelive.com/index. wml?id=1b6a5ecef91ff9*37819&first=true18:0430-JUL-05', 1, 0.9999999874099044)
# ('Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send GO to 86688 only 150p/msg. CC 08718720201 HG/Suite342/2Lands Row/W1J6HL', 1, 1.0)
# ('3 FREE TAROT TEXTS! Find out about your love life now! TRY 3 FOR FREE! Text CHANCE to 85555 16 only! After 3 Free, Msgs å£1.50 each', 1, 0.9999998079981912)
# ('Well done ENGLAND! Get the official poly ringtone or colour flag on yer mobile! text TONE or FLAG to 84199 NOW! Opt-out txt ENG STOP. Box39822 W111WX å£1.50', 1, 1.0)
# ("Today's Offer! Claim ur å£150 worth of discount vouchers! Text YES to 85023 now! SavaMob, member offers mobile! T Cs 08717898035. å£3.00 Sub. 16 . Unsub reply X", 1, 1.0)
# ('Double Mins & Double Txt & 1/2 price Linerental on Latest Orange Bluetooth mobiles. Call MobileUpd8 for the very latest offers. 08000839402 or call2optout/LF56', 1, 1.0)
# ('No 1 POLYPHONIC tone 4 ur mob every week! Just txt PT2 to 87575. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info', 1, 1.0)
# ('Customer service annoncement. You have a New Years delivery waiting for you. Please call 07046744435 now to arrange delivery', 1, 0.9999302118283959)
# ('Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16', 1, 1.0)
# ('URGENT, IMPORTANT INFORMATION FOR O2 USER. TODAY IS YOUR LUCKY DAY! 2 FIND OUT WHY LOG ONTO HTTP://WWW.URAWINNER.COM THERE IS A FANTASTIC SURPRISE AWAITING FOR YOU', 1, 1.0)
# ("Guess who am I?This is the first time I created a web page WWW.ASJESUS.COM read all I wrote. I'm waiting for your opinions. I want to be your friend 1/1", 1, 0.9783006643486055)
# ('Wanna have a laugh? Try CHIT-CHAT on your mobile now! Logon by txting the word: CHAT and send it to No: 8883 CM PO Box 4217 London W1A 6ZF 16+ 118p/msg rcvd', 1, 0.9999999999913812)
# ('Free entry to the gr8prizes wkly comp 4 a chance to win the latest Nokia 8800, PSP or å£250 cash every wk.TXT GREAT to 80878 http//www.gr8prizes.com 08715705022', 1, 1.0)
# ('18 days to Euro2004 kickoff! U will be kept informed of all the latest news and results daily. Unsubscribe send GET EURO STOP to 83222.', 1, 0.9999999999984965)
# ('You have won ?1,000 cash or a ?2,000 prize! To claim, call09050000327. T&C: RSTM, SW7 3SS. 150ppm', 1, 1.0)
# ('URGENT! Your mobile No *********** WON a å£2,000 Bonus Caller Prize on 02/06/03! This is the 2nd attempt to reach YOU! Call 09066362220 ASAP! BOX97N7QP, 150ppm', 1, 1.0)
# ('44 7732584351, Do you want a New Nokia 3510i colour phone DeliveredTomorrow? With 300 free minutes to any mobile + 100 free texts + Free Camcorder reply or call 08000930705.', 1, 1.0)
# ("Free entry in 2 a weekly comp for a chance to win an ipod. Txt POD to 80182 to get entry (std txt rate) T&C's apply 08452810073 for details 18+", 1, 1.0)
# ('complimentary 4 STAR Ibiza Holiday or å£10,000 cash needs your URGENT collection. 09066364349 NOW from Landline not to lose out! Box434SK38WP150PPM18+', 1, 0.9999999999964829)
# ('Cashbin.co.uk (Get lots of cash this weekend!) www.cashbin.co.uk Dear Welcome to the weekend We have got our biggest and best EVER cash give away!! These..', 1, 0.9999987485110357)
# ('Urgent! call 09066350750 from your landline. Your complimentary 4* Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+ ', 1, 1.0)
# ('Enjoy the jamster videosound gold club with your credits for 2 new videosounds+2 logos+musicnews! get more fun from jamster.co.uk! 16+only Help? call: 09701213186 ', 1, 0.9999999999999878)
# ('Do you want a New Nokia 3510i colour phone DeliveredTomorrow? With 300 free minutes to any mobile + 100 free texts + Free Camcorder reply or call 08000930705.', 1, 1.0)
# ('PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S.I.M. points. Call 08715203685 Identifier Code:4xx26 Expires 13/10/04', 1, 1.0)
# ('4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths ? Call MobilesDirect free on 08000938767 to update now! or2stoptxt', 1, 1.0)
# ('FREE entry into our å£250 weekly comp just send the word WIN to 80086 NOW. 18 T&C www.txttowin.co.uk', 1, 1.0)
# ('YES! The only place in town to meet exciting adult singles is now in the UK. Txt CHAT to 86688 now! 150p/Msg.', 1, 0.9999999996698803)
# ('SMS. ac Sptv: The New Jersey Devils and the Detroit Red Wings play Ice Hockey. Correct or Incorrect? End? Reply END SPTV', 1, 0.9055467705905951)
# ('Double Mins & 1000 txts on Orange tariffs. Latest Motorola, SonyEricsson & Nokia with Bluetooth FREE! Call MobileUpd8 on 08000839402 or call2optout/HF8', 1, 1.0)
# ('Wan2 win a Meet+Greet with Westlife 4 U or a m8? They are currently on what tour? 1)Unbreakable, 2)Untamed, 3)Unkempt. Text 1,2 or 3 to 83049. Cost 50p +std text', 1, 1.0)
# ('UR GOING 2 BAHAMAS! CallFREEFONE 08081560665 and speak to a live operator to claim either Bahamas cruise ofå£2000 CASH 18+only. To opt out txt X to 07786200117', 1, 1.0)
# ('FREE for 1st week! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates. www.getzed.co.uk POBox 36504 W45WQ 16+ norm150p/tone', 1, 1.0)
# ('Hi, Mobile no.  &lt;#&gt;  has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com', 0, 0.9338300256372553)
# ("For ur chance to win a å£250 wkly shopping spree TXT: SHOP to 80878. T's&C's www.txt-2-shop.com custcare 08715705022, 1x150p/wk", 1, 1.0)
# ('YOU 07801543489 are guaranteed the latests Nokia Phone, a 40GB iPod MP3 player or a å£500 prize! Txt word:COLLECT to No:83355! TC-LLC NY-USA 150p/Mt msgrcvd18+', 1, 1.0)
# ('URGENT! We are trying to contact U. Todays draw shows that you have won a å£800 prize GUARANTEED. Call 09050003091 from land line. Claim C52. Valid12hrs only', 1, 1.0)
# ('Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access! www.telediscount.co.uk', 1, 1.0)
# ('HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call', 1, 1.0)
# ('You are a winner U have been specially selected 2 receive å£1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+) ', 1, 1.0)
# ('Todays Voda numbers ending 7548 are selected to receive a $350 award. If you have a match please call 08712300220 quoting claim code 4041 standard rates app', 1, 1.0)
# ('URGENT! Your mobile No 077xxx WON a å£2,000 Bonus Caller Prize on 02/06/03! This is the 2nd attempt to reach YOU! Call 09066362206 ASAP! BOX97N7QP, 150ppm', 1, 1.0)
# ('Thanks for the Vote. Now sing along with the stars with Karaoke on your mobile. For a FREE link just reply with SING now.', 1, 0.9925749353185632)
# ('Someonone you know is trying to contact you via our dating service! To find out who it could be call from your mobile or landline 09064015307 BOX334SK38ch ', 1, 0.9999999983245247)
# ('Dont forget you can place as many FREE Requests with 1stchoice.co.uk as you wish. For more Information call 08707808226.', 1, 0.7810097816883719)
# ('Congrats! 2 mobile 3G Videophones R yours. call 09063458130 now! videochat wid your mates, play java games, Dload polyPH music, noline rentl.', 1, 1.0)
# ('wamma get laid?want real doggin locations sent direct to your mobile? join the UKs largest dogging network. txt dogs to 69696 now!nyt. ec2a. 3lp å£1.50/msg.', 1, 1.0)
# ("Hard LIVE 121 chat just 60p/min. Choose your girl and connect LIVE. Call 09094646899 now! Cheap Chat UK's biggest live service. VU BCM1896WC1N3XX", 1, 0.9999999999999842)
# ('HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com', 1, 1.0)
# ('Urgent! call 09066350750 from your landline. Your complimentary 4* Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+', 1, 1.0)
# ("More people are dogging in your area now. Call 09090204448 and join like minded guys. Why not arrange 1 yourself. There's 1 this evening. Aå£1.50 minAPN LS278BB", 1, 0.5776083272320346)
# ('Get 3 Lions England tone, reply lionm 4 mono or lionp 4 poly. 4 more go 2 www.ringtones.co.uk, the original n best. Tones 3GBP network operator rates apply', 1, 1.0)
# ("Congratulations YOU'VE Won. You're a Winner in our August å£1000 Prize Draw. Call 09066660100 NOW. Prize Code 2309.", 1, 0.9999999999974841)
# ('Welcome! Please reply with your AGE and GENDER to begin. e.g 24M', 1, 0.5519546593814656)
# ('Text PASS to 69669 to collect your polyphonic ringtones. Normal gprs charges apply only. Enjoy your tones', 1, 0.9999999872381073)
# ('You will recieve your tone within the next 24hrs. For Terms and conditions please see Channel U Teletext Pg 750', 1, 0.9999740544727109)
# ('A link to your picture has been sent. You can also use http://alto18.co.uk/wave/wave.asp?o=44345', 1, 0.9999499616539147)
# ("Hello from Orange. For 1 month's free access to games, news and sport, plus 10 free texts and 20 photo messages, reply YES. Terms apply: www.orange.co.uk/ow", 1, 1.0)
# ("1000's flirting NOW! Txt GIRL or BLOKE & ur NAME & AGE, eg GIRL ZOE 18 to 8007 to join and get chatting!", 1, 0.9999999999955455)
# ("If you don't, your prize will go to another customer. T&C at www.t-c.biz 18+ 150p/min Polo Ltd Suite 373 London W1J 6HL Please call back if busy ", 1, 1.0)
# ('Last Chance! Claim ur å£150 worth of discount vouchers today! Text SHOP to 85023 now! SavaMob, offers mobile! T Cs SavaMob POBOX84, M263UZ. å£3.00 Sub. 16', 1, 1.0)
# ('You have WON a guaranteed å£1000 cash or a å£2000 prize. To claim yr prize call our customer service representative on 08714712379 between 10am-7pm Cost 10p', 1, 1.0)
# ('URGENT!: Your Mobile No. was awarded a å£2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9755 BOX95QU', 1, 1.0)
# ('<Forwarded from 448712404000>Please CALL 08712404000 immediately as there is an urgent message waiting for you.', 1, 0.7375758827678368)
# ('-PLS STOP bootydelious (32/F) is inviting you to be her friend. Reply YES-434 or NO-434 See her: www.SMS.ac/u/bootydelious STOP? Send STOP FRND to 62468', 1, 0.9999999999699664)
# ('Got what it takes 2 take part in the WRC Rally in Oz? U can with Lucozade Energy! Text RALLY LE to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!', 1, 0.9999999999987434)
# ('Free tones Hope you enjoyed your new content. text stop to 61610 to unsubscribe. help:08712400602450p Provided by tones2you.co.uk', 1, 0.999999999997509)
# ('Someone U know has asked our dating service 2 contact you! Cant Guess who? CALL 09058091854 NOW all will be revealed. PO BOX385 M6 6WU', 1, 0.9999999999989959)
# ('U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094599', 1, 0.9999999995916456)
# ('You are awarded a SiPix Digital Camera! call 09061221061 from landline. Delivery within 28days. T Cs Box177. M221BP. 2yr warranty. 150ppm. 16 . p på£3.99', 1, 1.0)
# ('Tone Club: Your subs has now expired 2 re-sub reply MONOC 4 monos or POLYC 4 polys 1 weekly @ 150p per week Txt STOP 2 stop This msg free Stream 0871212025016', 1, 1.0)
# ('New TEXTBUDDY Chat 2 horny guys in ur area 4 just 25p Free 2 receive Search postcode or at gaytextbuddy.com. TXT ONE name to 89693. 08715500022 rpl Stop 2 cnl', 1, 0.9999999999999998)
# ("Plz note: if anyone calling from a mobile Co. &amp; asks u to type # &lt;#&gt;  or # &lt;#&gt; . Do not do so. Disconnect the call,coz it iz an attempt of 'terrorist' to make use of the sim card no. Itz confirmd by nokia n motorola n has been verified by CNN IBN.", 0, 0.9991412865031271)
# ('URGENT! Your Mobile number has been awarded with a å£2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm', 1, 1.0)
# ('(Bank of Granite issues Strong-Buy) EXPLOSIVE PICK FOR OUR MEMBERS *****UP OVER 300% *********** Nasdaq Symbol CDGT That is a $5.00 per..', 1, 0.9999998289004287)
# ('FREE MESSAGE Activate your 500 FREE Text Messages by replying to this message with the word FREE For terms & conditions, visit www.07781482378.com', 1, 0.9999999999871084)
# ('You are being ripped off! Get your mobile content from www.clubmoby.com call 08717509990 poly/true/Pix/Ringtones/Games six downloads for only 3', 1, 0.9999999999999251)
# ('HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call', 1, 1.0)
# ('Sunshine Quiz! Win a super Sony DVD recorder if you canname the capital of Australia? Text MQUIZ to 82277. B', 1, 0.9999993787187503)
# ('FREE RINGTONE text FIRST to 87131 for a poly or text GET to 87131 for a true tone! Help? 0845 2814032 16 after 1st free, tones are 3xå£150pw to eå£nd txt stop', 1, 1.0)
# ("For ur chance to win å£250 cash every wk TXT: PLAY to 83370. T's&C's www.music-trivia.net custcare 08715705022, 1x150p/wk.", 1, 1.0)
# ('FREE>Ringtone! Reply REAL or POLY eg REAL1 1. PushButton 2. DontCha 3. BabyGoodbye 4. GoldDigger 5. WeBeBurnin 1st tone FREE and 6 more when u join for å£3/wk', 1, 0.9999999999998689)
# ('Shop till u Drop, IS IT YOU, either 10K, 5K, å£500 Cash or å£100 Travel voucher, Call now, 09064011000. NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary', 1, 1.0)
# ('Win the newest åÒHarry Potter and the Order of the Phoenix (Book 5) reply HARRY, answer 5 questions - chance to be the first among readers!', 1, 0.9999999865672307)
# ('Want explicit SEX in 30 secs? Ring 02073162414 now! Costs 20p/min', 1, 0.9957463034685089)
# ('Thanks for your subscription to Ringtone UK your mobile will be charged å£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged', 1, 0.9999999967149831)
# ('PRIVATE! Your 2003 Account Statement for 07753741225 shows 800 un-redeemed S. I. M. points. Call 08715203677 Identifier Code: 42478 Expires 24/10/04', 1, 1.0)
# ('Fantasy Football is back on your TV. Go to Sky Gamestar on Sky Active and play å£250k Dream Team. Scoring starts on Saturday, so register now!SKY OPT OUT to 88088', 1, 0.9999999999996743)
# ('You can stop further club tones by replying \\STOP MIX\\" See my-tone.com/enjoy. html for terms. Club tones cost GBP4.50/week. MFL', 1, 0.999999999872786)
# ('Urgent! Please call 09061213237 from a landline. å£5000 cash or a 4* holiday await collection. T &Cs SAE PO Box 177 M227XY. 16+', 1, 1.0)

# %% [markdown]
# -결과
#
#  *출력된 결과는 테스트 데이터중 스팸메일의 경우 출력되어 스팸메일의 내용과 확률을 보여줍니다.
